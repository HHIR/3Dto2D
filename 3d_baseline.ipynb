# %% [markdown]
# <a href="https://colab.research.google.com/github/Hosseinhashemiir/3Dto2D/blob/master/3d_baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/miu200521358/3d-pose-baseline-vmd.git
# Out:
# Cloning into '3d-pose-baseline-vmd'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 212 (delta 2), reused 7 (delta 2), pack-reused 202
# Receiving objects: 100% (212/212), 44.23 MiB | 20.86 MiB/s, done.
# Resolving deltas: 100% (120/120), done.

# %%
# %cd 3d-pose-baseline-vmd
# Out:
# /content/3d-pose-baseline-vmd

# %%
# !mkdir data
# %cd data
# Out:
# /content/3d-pose-baseline-vmd/data

# %%
# !wget https://www.dropbox.com/s/e35qv3n6zlkouki/h36m.zip
# Out:
# --2018-11-29 09:30:52--  https://www.dropbox.com/s/e35qv3n6zlkouki/h36m.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.1, 2620:100:6021:1::a27d:4101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/e35qv3n6zlkouki/h36m.zip [following]
# --2018-11-29 09:30:52--  https://www.dropbox.com/s/raw/e35qv3n6zlkouki/h36m.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc1103d1f4ac44ab98928dc01033.dl.dropboxusercontent.com/cd/0/inline/AWh08RGMUPhfqcqjvAkW06YM7ynNTHTy4Eljj_kWPWQ4EoN83DSBsRN7U3I7rq_xcempLpknhAFX28ZDF8_FlonvOGu4tnUEezQ4HTkQsT0lXWaQ13DEJnP1FsiJ7XbyuELdISouYIBhLyoWnYp8quJVBrxCttyGukOQPLMGLUA1ZCKroV-6606are9_6NDuUZA/file [following]
# ...

# %%
# !unzip h36m.zip
# Out:
# Archive:  h36m.zip
#    creating: h36m/
#   inflating: h36m/cameras.h5
#    creating: h36m/S11/
#    creating: h36m/S9/
#    creating: h36m/S8/
#    creating: h36m/S7/
#    creating: h36m/S6/
#    creating: h36m/S5/
#    creating: h36m/S1/
#    creating: h36m/S11/MyPoses/
#    creating: h36m/S11/StackedHourglass/
#   inflating: h36m/S11/StackedHourglass/Posing_1.60457274.h5
#   inflating: h36m/S11/StackedHourglass/Greeting.60457274.h5
#   inflating: h36m/S11/StackedHourglass/Smoking.60457274.h5
#   inflating: h36m/S11/StackedHourglass/Phoning_2.55011271.h5
#   inflating: h36m/S11/StackedHourglass/Photo.54138969.h5
#   inflating: h36m/S11/StackedHourglass/Purchases_1.55011271.h5
#   inflating: h36m/S11/StackedHourglass/Directions.58860488.h5
#   inflating: h36m/S11/StackedHourglass/Smoking_2.60457274.h5
#   inflating: h36m/S11/StackedHourglass/SittingDown_1.60457274.h5
#   inflating: h36m/S11/StackedHourglass/Walking.58860488.h5
# ...

# %%
# %cd ..
# Out:
# /content/3d-pose-baseline-vmd

# %%
# %cd

# %%
# !pip install imageio
# Out:
# ...
#     100% |████████████████████████████████| 3.3MB 10.4MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/e0/43/31/605de9372ceaf657f152d3d5e82f42cf265d81db8bbe63cde1
# Successfully built imageio
# ...

# %%
# !python src/openpose_3dpose_sandbox_vmd.py --camera_frame --residual --batch_norm --dropout 0.5 --max_norm --evaluateActionWise --use_sh --epochs 200 --load 4874200 --gif_fps 30 --verbose 3 --openpose ./output --person_idx 1
# Out:
# experiments/All/dropout_0.5/epochs_200/lr_0.001/residual/depth_2/ls1024/bs64/np/maxnorm/batch_normalization/use_stacked_hourglass/predict_17
# DEBUG:__main__:FLAGS.person_idx=1
# INFO:openpose_utils:start reading data: ./output
# Traceback (most recent call last):
#   File "src/openpose_3dpose_sandbox_vmd.py", line 266, in <module>
#     tf.app.run()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/platform/app.py", line 125, in run
#     _sys.exit(main(argv))
#   File "src/openpose_3dpose_sandbox_vmd.py", line 65, in main
#     smoothed = openpose_utils.read_openpose_json(openpose_output_dir, idx, level[FLAGS.verbose] == 3)
#   File "/content/3d-pose-baseline-vmd/src/openpose_utils.py", line 28, in read_openpose_json
#     json_files = os.listdir(openpose_output_dir)
# FileNotFoundError: [Errno 2] No such file or directory: './output'

# %%
# !ls
# Out:
# data	     imgs		OpenposeTo3D.bat		 README.md
# doc	     ISSUE_TEMPLATE.md	output_3d_20181129_093831_idx01  src
# experiments  LICENCE		README-ArashHosseini.md

# %%
# !pip install gdown
# Out:
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/97/90/fa/25654eb65da3e6da7752db71a164e0eb8f7a6fb4335eeb46ab
# Successfully built gdown
# ...

# %%
# !gdown https://drive.google.com/uc?id=1v7ccpms3ZR8ExWWwVfcSpjMsGscDYH7_
# !unzip experiments.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1v7ccpms3ZR8ExWWwVfcSpjMsGscDYH7_
# To: /content/3d-pose-baseline-vmd/experiments.zip
# 1.00GB [00:06, 162MB/s]
# Archive:  experiments.zip
#    creating: experiments/All/dropout_0.5/epochs_1/
#    creating: experiments/All/dropout_0.5/epochs_1/lr_0.001/
#    creating: experiments/All/dropout_0.5/epochs_1/lr_0.001/residual/
#    creating: experiments/All/dropout_0.5/epochs_1/lr_0.001/residual/depth_2/
#    creating: experiments/All/dropout_0.5/epochs_1/lr_0.001/residual/depth_2/linear_size1024/
#    creating: experiments/All/dropout_0.5/epochs_1/lr_0.001/residual/depth_2/linear_size1024/batch_size_64/
#    creating: experiments/All/dropout_0.5/epochs_1/lr_0.001/residual/depth_2/linear_size1024/batch_size_64/no_procrustes/
#    creating: experiments/All/dropout_0.5/epochs_1/lr_0.001/residual/depth_2/linear_size1024/batch_size_64/no_procrustes/maxnorm/
# ...

# %%
# !ls
# Out:
# data		 imgs		    output_3d_20181129_093831_idx01
# doc		 ISSUE_TEMPLATE.md  README-ArashHosseini.md
# experiments	 LICENCE	    README.md
# experiments.zip  OpenposeTo3D.bat   src

# %%
# !gdown https://drive.google.com/uc?id=1q5K8j3UqpS6YvdeNtMqfbgUDFBkf3geR
# !unzip output.zip

#https://drive.google.com/file/d/1q5K8j3UqpS6YvdeNtMqfbgUDFBkf3geR/view?usp=sharing
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1q5K8j3UqpS6YvdeNtMqfbgUDFBkf3geR
# To: /content/3d-pose-baseline-vmd/output.zip
# 14.4MB [00:00, 200MB/s]
# Archive:  output.zip
#    creating: output/
#   inflating: output/qq_000000000000_keypoints.json
#   inflating: output/qq_000000000001_keypoints.json
#   inflating: output/qq_000000000002_keypoints.json
#   inflating: output/qq_000000000003_keypoints.json
#   inflating: output/qq_000000000004_keypoints.json
#   inflating: output/qq_000000000005_keypoints.json
#   inflating: output/qq_000000000006_keypoints.json
#   inflating: output/qq_000000000007_keypoints.json
#   inflating: output/qq_000000000008_keypoints.json
#   inflating: output/qq_000000000009_keypoints.json
#   inflating: output/qq_000000000010_keypoints.json
#   inflating: output/qq_000000000011_keypoints.json
#   inflating: output/qq_000000000012_keypoints.json
#   inflating: output/qq_000000000013_keypoints.json
# ...

# %%
# !python src/openpose_3dpose_sandbox_vmd.py --camera_frame --residual --batch_norm --dropout 0.5 --max_norm --evaluateActionWise --use_sh --epochs 200 --load 4874200 --gif_fps 30 --verbose 3 --openpose ./output --person_idx 1
# Out:
# experiments/All/dropout_0.5/epochs_200/lr_0.001/residual/depth_2/ls1024/bs64/np/maxnorm/batch_normalization/use_stacked_hourglass/predict_17
# DEBUG:__main__:FLAGS.person_idx=1
# INFO:openpose_utils:start reading data: ./output
# Traceback (most recent call last):
#   File "src/openpose_3dpose_sandbox_vmd.py", line 266, in <module>
#     tf.app.run()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/platform/app.py", line 125, in run
#     _sys.exit(main(argv))
#   File "src/openpose_3dpose_sandbox_vmd.py", line 65, in main
#     smoothed = openpose_utils.read_openpose_json(openpose_output_dir, idx, level[FLAGS.verbose] == 3)
#   File "/content/3d-pose-baseline-vmd/src/openpose_utils.py", line 84, in read_openpose_json
#     _tmp_points[n][_data_idx] = _tmp_data[o]
# IndexError: list index out of range
